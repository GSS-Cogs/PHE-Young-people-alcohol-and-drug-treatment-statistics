# %% [markdown]
# Table 2.7.2: Individual vulnerabilities identified among all young people starting treatment in 2016-17

# %%
from gssutils import *

if is_interactive():
    import requests
    from cachecontrol import CacheControl
    from cachecontrol.caches.file_cache import FileCache
    from cachecontrol.heuristics import LastModified
    from pathlib import Path

    session = CacheControl(requests.Session(),
                           cache=FileCache('.cache'),
                           heuristic=LastModified())

    sourceFolder = Path('in')
    sourceFolder.mkdir(exist_ok=True)

    inputURL = 'https://www.gov.uk/government/uploads/system/uploads/attachment_data/file/664944/'\
                    'Young-people-statistics-data-tables-from-the-national-drug-treatment-monitoring-system-2016-2017.xls'
    inputFile = sourceFolder / 'Young-people-statistics-data-tables-from-the-national-drug-treatment-monitoring-system-2016-2017.xls'
    response = session.get(inputURL)
    with open(inputFile, 'wb') as f:
      f.write(response.content)

# %%
tab = loadxlstabs(inputFile, sheetids='2.7.2 Vulnerabilities')[0]
# Out:
# Loading in\Young-people-statistics-data-tables-from-the-national-drug-treatment-monitoring-system-2016-2017.xls which has size 281600 bytes
# Table names: ['2.7.2 Vulnerabilities']

# %%
observations = tab.excel_ref('B5').expand(DOWN).expand(RIGHT).is_not_blank()
observations
# Out:
# {<G15 0.07>, <F20 168.0>, <B19 92.0>, <C16 0.14>, <D8 1597.0>, <F6 6817.0>, <D12 1357.0>, <E7 0.39>, <B5 3386.0>, <F22 11753.0>, <E6 0.55>, <C9 0.28>, <E5 0.83>, <D7 3009.0>, <C12 0.13>, <G19 0.02>, <G16 0.06>, <E16 0.02>, <G18 0.02>, <B14 451.0>, <D5 6467.0>, <F7 3749.0>, <D20 106.0>, <B11 1225.0>, <G11 0.17>, <C6 0.64>, <D9 1411.0>, <B7 740.0>, <D11 719.0>, <E20 0.01>, <G17 0.04>, <C11 0.31>, <B20 62.0>, <G13 0.12>, <F15 857.0>, <D18 123.0>, <G21 0.01>, <G9 0.21>, <D16 123.0>, <F18 227.0>, <B6 2527.0>, <C18 0.03>, <C14 0.11>, <E22 1.0>, <F10 2108.0>, <E9 0.18>, <C22 1.0>, <E18 0.02>, <E14 0.06>, <C7 0.19>, <F16 688.0>, <F19 221.0>, <B17 230.0>, <B9 1093.0>, <E19 0.02>, <F5 9853.0>, <F17 414.0>, <F14 928.0>, <B13 542.0>, <E10 0.15>, <C10 0.24>, <G20 0.01>, <B16 565.0>, <D14 477.0>, <E8 0.2>, <D15 469.0>, <F11 1944.0>, <D6 4290.0>, <G12 0.16>, <F12 1869.0>, <C15 0.1>, <G5 0.84>, <F13 1400.0>, <B10 947.0>, <C5 0.86>, <C8 0.28>, <E11 0.09>, <E21 0.01>, <B21 43.0>, <F9 2504.0>, <D21 51.0>, <D13 858.0>, <G22 1.0>, <C21 0.01>, <G8 0.23>, <B15 388.0>, <D19 129.0>, <C17 0.06>, <E13 0.11>, <D17 184.0>, <B8 1110.0>, <C20 0.02>, <F8 2707.0>, <G14 0.08>, <B12 512.0>, <D10 1161.0>, <C19 0.02>, <E15 0.06>, <G7 0.32>, <E17 0.02>, <E12 0.17>, <G10 0.18>, <D22 7804.0>, <B18 104.0>, <C13 0.14>, <G6 0.58>, <B22 3949.0>, <F21 94.0>}

# %%
age = tab.excel_ref('A5').expand(DOWN).is_not_blank()
age
# Out:
# {<A11 'Self-harm'>, <A21 'Injecting'>, <A18 'Pregnant and/or parent'>, <A12 'NEET'>, <A5 'Early onset of substance misuse'>, <A6 'Poly substance user'>, <A10 'Mental health problem'>, <A22 'Total new presentations'>, <A16 'Sexual exploitation'>, <A14 'Child Protection Plan'>, <A13 'Looked after child'>, <A7 'Antisocial behaviour'>, <A9 'Affected by domestic abuse'>, <A19 'Opiate and/or crack use'>, <A15 'Child in need'>, <A17 'High risk alcohol user'>, <A20 'Housing problem'>, <A8 "Affected by others' substance misuse">}

# %%
sex = tab.excel_ref('B3').expand(RIGHT).is_not_blank() 
sex
# Out:
# {<F3 'Persons'>, <B3 'Female'>, <D3 'Male'>}

# %%
measuretype = tab.excel_ref('B4').expand(RIGHT).is_not_blank() 
measuretype
# Out:
# {<F4 'n'>, <E4 '%'>, <C4 '%'>, <B4 'n'>, <D4 'n'>, <G4 '%'>}

# %%
Dimensions = [
            HDim(age,'Basis of treatment',DIRECTLY,LEFT),
            HDim(sex,'Clients in treatment',CLOSEST,LEFT),
            HDim(measuretype,'Measure Type',DIRECTLY,ABOVE),
            HDimConst('Unit','People')            
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
# if is_interactive():
#     savepreviewhtml(c1)

# %%
new_table = c1.topandas()
new_table
# Out:
#           OBS                    Basis of treatment Clients in treatment  \
# 0     3386.00       Early onset of substance misuse               Female
# 1        0.86       Early onset of substance misuse               Female
# 2     6467.00       Early onset of substance misuse                 Male
# 3        0.83       Early onset of substance misuse                 Male
# 4     9853.00       Early onset of substance misuse              Persons
# 5        0.84       Early onset of substance misuse              Persons
# 6     2527.00                   Poly substance user               Female
# 7        0.64                   Poly substance user               Female
# 8     4290.00                   Poly substance user                 Male
# 9        0.55                   Poly substance user                 Male
# 10    6817.00                   Poly substance user              Persons
# 11       0.58                   Poly substance user              Persons
# 12     740.00                  Antisocial behaviour               Female
# 13       0.19                  Antisocial behaviour               Female
# 14    3009.00                  Antisocial behaviour                 Male
# 15       0.39                  Antisocial behaviour                 Male
# 16    3749.00                  Antisocial behaviour              Persons
# 17       0.32                  Antisocial behaviour              Persons
# 18    1110.00  Affected by others' substance misuse               Female
# 19       0.28  Affected by others' substance misuse               Female
# 20    1597.00  Affected by others' substance misuse                 Male
# 21       0.20  Affected by others' substance misuse                 Male
# 22    2707.00  Affected by others' substance misuse              Persons
# 23       0.23  Affected by others' substance misuse              Persons
# 24    1093.00            Affected by domestic abuse               Female
# 25       0.28            Affected by domestic abuse               Female
# 26    1411.00            Affected by domestic abuse                 Male
# 27       0.18            Affected by domestic abuse                 Male
# 28    2504.00            Affected by domestic abuse              Persons
# 29       0.21            Affected by domestic abuse              Persons
# ..        ...                                   ...                  ...
# 78     104.00                Pregnant and/or parent               Female
# 79       0.03                Pregnant and/or parent               Female
# 80     123.00                Pregnant and/or parent                 Male
# 81       0.02                Pregnant and/or parent                 Male
# 82     227.00                Pregnant and/or parent              Persons
# 83       0.02                Pregnant and/or parent              Persons
# 84      92.00               Opiate and/or crack use               Female
# 85       0.02               Opiate and/or crack use               Female
# 86     129.00               Opiate and/or crack use                 Male
# 87       0.02               Opiate and/or crack use                 Male
# 88     221.00               Opiate and/or crack use              Persons
# 89       0.02               Opiate and/or crack use              Persons
# 90      62.00                       Housing problem               Female
# 91       0.02                       Housing problem               Female
# 92     106.00                       Housing problem                 Male
# 93       0.01                       Housing problem                 Male
# 94     168.00                       Housing problem              Persons
# 95       0.01                       Housing problem              Persons
# 96      43.00                             Injecting               Female
# 97       0.01                             Injecting               Female
# 98      51.00                             Injecting                 Male
# 99       0.01                             Injecting                 Male
# 100     94.00                             Injecting              Persons
# 101      0.01                             Injecting              Persons
# 102   3949.00               Total new presentations               Female
# 103      1.00               Total new presentations               Female
# 104   7804.00               Total new presentations                 Male
# 105      1.00               Total new presentations                 Male
# 106  11753.00               Total new presentations              Persons
# 107      1.00               Total new presentations              Persons
#
#     Measure Type    Unit
# 0              n  People
# 1              %  People
# 2              n  People
# 3              %  People
# 4              n  People
# 5              %  People
# 6              n  People
# 7              %  People
# 8              n  People
# 9              %  People
# 10             n  People
# 11             %  People
# 12             n  People
# 13             %  People
# 14             n  People
# 15             %  People
# 16             n  People
# 17             %  People
# 18             n  People
# 19             %  People
# 20             n  People
# 21             %  People
# 22             n  People
# 23             %  People
# 24             n  People
# 25             %  People
# 26             n  People
# 27             %  People
# 28             n  People
# 29             %  People
# ..           ...     ...
# 78             n  People
# 79             %  People
# 80             n  People
# 81             %  People
# 82             n  People
# 83             %  People
# 84             n  People
# 85             %  People
# 86             n  People
# 87             %  People
# 88             n  People
# 89             %  People
# 90             n  People
# 91             %  People
# 92             n  People
# 93             %  People
# 94             n  People
# 95             %  People
# 96             n  People
# 97             %  People
# 98             n  People
# 99             %  People
# 100            n  People
# 101            %  People
# 102            n  People
# 103            %  People
# 104            n  People
# 105            %  People
# 106            n  People
# 107            %  People
#
# [108 rows x 5 columns]

# %%
new_table = new_table[new_table['OBS'] != 0 ]

# %%
new_table.columns = ['Value' if x=='OBS' else x for x in new_table.columns]

# %%
new_table['Basis of treatment'] = 'Vulnerability' +'/'+ new_table['Basis of treatment']

# %%
new_table.head()
# Out:
#      Value                             Basis of treatment  \
# 0  3386.00  Vulnerability/Early onset of substance misuse
# 1     0.86  Vulnerability/Early onset of substance misuse
# 2  6467.00  Vulnerability/Early onset of substance misuse
# 3     0.83  Vulnerability/Early onset of substance misuse
# 4  9853.00  Vulnerability/Early onset of substance misuse
#
#   Clients in treatment Measure Type    Unit
# 0               Female            n  People
# 1               Female            %  People
# 2                 Male            n  People
# 3                 Male            %  People
# 4              Persons            n  People

# %%
new_table['Basis of treatment'].unique()
# Out:
# array(['Vulnerability/Early onset of substance misuse',
#        'Vulnerability/Poly substance user',
#        'Vulnerability/Antisocial behaviour',
#        "Vulnerability/Affected by others' substance misuse",
#        'Vulnerability/Affected by domestic abuse',
#        'Vulnerability/Mental health problem', 'Vulnerability/Self-harm',
#        'Vulnerability/NEET', 'Vulnerability/Looked after child',
#        'Vulnerability/Child Protection Plan',
#        'Vulnerability/Child in need', 'Vulnerability/Sexual exploitation',
#        'Vulnerability/High risk alcohol user',
#        'Vulnerability/Pregnant and/or parent',
#        'Vulnerability/Opiate and/or crack use',
#        'Vulnerability/Housing problem', 'Vulnerability/Injecting',
#        'Vulnerability/Total new presentations'], dtype=object)

# %%
new_table['Clients in treatment'] = new_table['Clients in treatment'].map(
    lambda x: {
        'Female' : 'F', 
        'Male' : 'M',
        'Persons' : 'T'
        }.get(x, x))

# %%
new_table.head()
# Out:
#      Value                             Basis of treatment  \
# 0  3386.00  Vulnerability/Early onset of substance misuse
# 1     0.86  Vulnerability/Early onset of substance misuse
# 2  6467.00  Vulnerability/Early onset of substance misuse
# 3     0.83  Vulnerability/Early onset of substance misuse
# 4  9853.00  Vulnerability/Early onset of substance misuse
#
#   Clients in treatment Measure Type    Unit
# 0                    F            n  People
# 1                    F            %  People
# 2                    M            n  People
# 3                    M            %  People
# 4                    T            n  People

# %%
new_table['Measure Type'] = new_table['Measure Type'].map(
    lambda x: {
        'n' : 'Count', 
        '%' : 'Percentage',
        }.get(x, x))

# %%
new_table.tail()
# Out:
#        Value                     Basis of treatment Clients in treatment  \
# 103      1.0  Vulnerability/Total new presentations                    F
# 104   7804.0  Vulnerability/Total new presentations                    M
# 105      1.0  Vulnerability/Total new presentations                    M
# 106  11753.0  Vulnerability/Total new presentations                    T
# 107      1.0  Vulnerability/Total new presentations                    T
#
#     Measure Type    Unit
# 103   Percentage  People
# 104        Count  People
# 105   Percentage  People
# 106        Count  People
# 107   Percentage  People

# %%
new_table.dtypes
# Out:
# Value                   float64
# Basis of treatment       object
# Clients in treatment     object
# Measure Type             object
# Unit                     object
# dtype: object

# %%
new_table['Value'] = new_table['Value'].astype(str)

# %%
new_table.head(3)
# Out:
#     Value                             Basis of treatment Clients in treatment  \
# 0  3386.0  Vulnerability/Early onset of substance misuse                    F
# 1    0.86  Vulnerability/Early onset of substance misuse                    F
# 2  6467.0  Vulnerability/Early onset of substance misuse                    M
#
#   Measure Type    Unit
# 0        Count  People
# 1   Percentage  People
# 2        Count  People

# %%
new_table['Period'] = '2016-17'
new_table['Substance'] = 'All'
new_table = new_table[['Period','Basis of treatment','Substance','Clients in treatment','Measure Type','Value','Unit']]

# %%
if is_interactive():
    SubstancetinationFolder = Path('out')
    SubstancetinationFolder.mkdir(exist_ok=True, parents=True)
    new_table.to_csv(SubstancetinationFolder / ('table2.7.2.csv'), index = False)

# %%
new_table.head()
# Out:
#     Period                             Basis of treatment Substance  \
# 0  2016-17  Vulnerability/Early onset of substance misuse       All
# 1  2016-17  Vulnerability/Early onset of substance misuse       All
# 2  2016-17  Vulnerability/Early onset of substance misuse       All
# 3  2016-17  Vulnerability/Early onset of substance misuse       All
# 4  2016-17  Vulnerability/Early onset of substance misuse       All
#
#   Clients in treatment Measure Type   Value    Unit
# 0                    F        Count  3386.0  People
# 1                    F   Percentage    0.86  People
# 2                    M        Count  6467.0  People
# 3                    M   Percentage    0.83  People
# 4                    T        Count  9853.0  People
