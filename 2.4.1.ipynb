# %% [markdown]
# Table 2.4.1: Source of referral of all treatment episodes 2016-17

# %%
from gssutils import *

if is_interactive():
    import requests
    from cachecontrol import CacheControl
    from cachecontrol.caches.file_cache import FileCache
    from cachecontrol.heuristics import LastModified
    from pathlib import Path

    session = CacheControl(requests.Session(),
                           cache=FileCache('.cache'),
                           heuristic=LastModified())

    sourceFolder = Path('in')
    sourceFolder.mkdir(exist_ok=True)

    inputURL = 'https://www.gov.uk/government/uploads/system/uploads/attachment_data/file/664944/'\
                    'Young-people-statistics-data-tables-from-the-national-drug-treatment-monitoring-system-2016-2017.xls'
    inputFile = sourceFolder / 'Young-people-statistics-data-tables-from-the-national-drug-treatment-monitoring-system-2016-2017.xls'
    response = session.get(inputURL)
    with open(inputFile, 'wb') as f:
      f.write(response.content)

# %%
tab = loadxlstabs(inputFile, sheetids='2.4.1 Referral Source')[0]
# Out:
# Loading in\Young-people-statistics-data-tables-from-the-national-drug-treatment-monitoring-system-2016-2017.xls which has size 281600 bytes
# Table names: ['2.4.1 Referral Source']

# %%
observations = tab.excel_ref('B4').expand(DOWN).expand(RIGHT).is_not_blank()
observations
# Out:
# {<B10 182.0>, <C21 0.04>, <B30 17703.0>, <C30 1.0>, <B15 305.0>, <B29 263.0>, <B9 3803.0>, <B16 2727.0>, <B24 168.0>, <C19 0.11>, <C5 0.04>, <C27 0.09>, <C4 0.22>, <C24 0.01>, <B23 238.0>, <C23 0.01>, <B5 769.0>, <C12 0.25>, <B25 112.0>, <B18 882.0>, <B7 7.0>, <C17 0.06>, <C26 0.0>, <C25 0.01>, <C28 0.02>, <C20 0.07>, <B8 5168.0>, <C22 0.02>, <B12 4358.0>, <B13 2095.0>, <B31 20.0>, <B17 1091.0>, <B28 294.0>, <C16 0.15>, <B32 17723.0>, <B6 420.0>, <B4 3972.0>, <B26 69.0>, <C9 0.21>, <C14 0.02>, <C11 0.02>, <C18 0.05>, <C29 0.01>, <B21 742.0>, <B19 1973.0>, <C6 0.02>, <C8 0.29>, <B22 324.0>, <B20 1267.0>, <C13 0.12>, <C7 0.0>, <C15 0.02>, <B11 373.0>, <B14 327.0>, <C10 0.01>, <B27 1653.0>}

# %%
referral = tab.excel_ref('A4').expand(DOWN).is_not_blank() - tab.excel_ref('A32')
referral
# Out:
# {<A28 'YP housing'>, <A21 'CAMHS'>, <A23 'A&E'>, <A16 'Social care total'>, <A17 'Self'>, <A10 'YP secure estate'>, <A25 'Hospital'>, <A24 'GP'>, <A4 'Mainstream education'>, <A9 'YOT'>, <A29 'Other'>, <A30 'Total (episodes)'>, <A18 'Relative, family, friend or concerned other'>, <A12 'Youth / criminal justice total'>, <A8 'Education total'>, <A20 'Substance misuse total'>, <A6 'Education service'>, <A13 'Children and family services'>, <A15 'Social services'>, <A7 'Other'>, <A14 'Looked after child services'>, <A26 'Other'>, <A11 'Other'>, <A27 'Health total'>, <A22 'School nurse'>, <A31 'Missing or inconsistent data'>, <A5 'Alternative education'>, <A19 'Self, family & friends total'>}

# %%
measuretype = tab.excel_ref('B3').expand(RIGHT).is_not_blank() 
measuretype
# Out:
# {<C3 '%'>, <B3 'n'>}

# %%
Dimensions = [
            HDimConst('Substance','All'),
            HDim(referral,'Basis of treatment',DIRECTLY,LEFT),
            HDim(measuretype,'Measure Type',DIRECTLY,ABOVE),
            HDimConst('Unit','People')            
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
# if is_interactive():
#     savepreviewhtml(c1)

# %%
new_table = c1.topandas()
new_table
# Out:
#          OBS Substance                           Basis of treatment  \
# 0    3972.00       All                         Mainstream education
# 1       0.22       All                         Mainstream education
# 2     769.00       All                        Alternative education
# 3       0.04       All                        Alternative education
# 4     420.00       All                            Education service
# 5       0.02       All                            Education service
# 6       7.00       All                                        Other
# 7       0.00       All                                        Other
# 8    5168.00       All                              Education total
# 9       0.29       All                              Education total
# 10   3803.00       All                                          YOT
# 11      0.21       All                                          YOT
# 12    182.00       All                             YP secure estate
# 13      0.01       All                             YP secure estate
# 14    373.00       All                                        Other
# 15      0.02       All                                        Other
# 16   4358.00       All               Youth / criminal justice total
# 17      0.25       All               Youth / criminal justice total
# 18   2095.00       All                 Children and family services
# 19      0.12       All                 Children and family services
# 20    327.00       All                  Looked after child services
# 21      0.02       All                  Looked after child services
# 22    305.00       All                              Social services
# 23      0.02       All                              Social services
# 24   2727.00       All                            Social care total
# 25      0.15       All                            Social care total
# 26   1091.00       All                                         Self
# 27      0.06       All                                         Self
# 28    882.00       All  Relative, family, friend or concerned other
# 29      0.05       All  Relative, family, friend or concerned other
# 30   1973.00       All                 Self, family & friends total
# 31      0.11       All                 Self, family & friends total
# 32   1267.00       All                       Substance misuse total
# 33      0.07       All                       Substance misuse total
# 34    742.00       All                                        CAMHS
# 35      0.04       All                                        CAMHS
# 36    324.00       All                                 School nurse
# 37      0.02       All                                 School nurse
# 38    238.00       All                                          A&E
# 39      0.01       All                                          A&E
# 40    168.00       All                                           GP
# 41      0.01       All                                           GP
# 42    112.00       All                                     Hospital
# 43      0.01       All                                     Hospital
# 44     69.00       All                                        Other
# 45      0.00       All                                        Other
# 46   1653.00       All                                 Health total
# 47      0.09       All                                 Health total
# 48    294.00       All                                   YP housing
# 49      0.02       All                                   YP housing
# 50    263.00       All                                        Other
# 51      0.01       All                                        Other
# 52  17703.00       All                             Total (episodes)
# 53      1.00       All                             Total (episodes)
# 54     20.00       All                 Missing or inconsistent data
# 55  17723.00       All                                         None
#
#    Measure Type    Unit
# 0             n  People
# 1             %  People
# 2             n  People
# 3             %  People
# 4             n  People
# 5             %  People
# 6             n  People
# 7             %  People
# 8             n  People
# 9             %  People
# 10            n  People
# 11            %  People
# 12            n  People
# 13            %  People
# 14            n  People
# 15            %  People
# 16            n  People
# 17            %  People
# 18            n  People
# 19            %  People
# 20            n  People
# 21            %  People
# 22            n  People
# 23            %  People
# 24            n  People
# 25            %  People
# 26            n  People
# 27            %  People
# 28            n  People
# 29            %  People
# 30            n  People
# 31            %  People
# 32            n  People
# 33            %  People
# 34            n  People
# 35            %  People
# 36            n  People
# 37            %  People
# 38            n  People
# 39            %  People
# 40            n  People
# 41            %  People
# 42            n  People
# 43            %  People
# 44            n  People
# 45            %  People
# 46            n  People
# 47            %  People
# 48            n  People
# 49            %  People
# 50            n  People
# 51            %  People
# 52            n  People
# 53            %  People
# 54            n  People
# 55            n  People

# %%
new_table = new_table[new_table['OBS'] != 0 ]

# %%
new_table.columns = ['Value' if x=='OBS' else x for x in new_table.columns]

# %%
new_table['Basis of treatment'] = new_table['Basis of treatment'].map(
    lambda x: {
        'Total (episodes)' : 'All episodes' 
        }.get(x, x))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
new_table['Basis of treatment'].fillna('All episodes including missing and inconsistent data', inplace = True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5434: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
new_table['Basis of treatment'] = 'Referral source/' + new_table['Basis of treatment']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
new_table.head()
# Out:
#      Value Substance                     Basis of treatment Measure Type  \
# 0  3972.00       All   Referral source/Mainstream education            n
# 1     0.22       All   Referral source/Mainstream education            %
# 2   769.00       All  Referral source/Alternative education            n
# 3     0.04       All  Referral source/Alternative education            %
# 4   420.00       All      Referral source/Education service            n
#
#      Unit
# 0  People
# 1  People
# 2  People
# 3  People
# 4  People

# %%
new_table['Clients in treatment'] = 'All young clients'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
new_table.head()
# Out:
#      Value Substance                     Basis of treatment Measure Type  \
# 0  3972.00       All   Referral source/Mainstream education            n
# 1     0.22       All   Referral source/Mainstream education            %
# 2   769.00       All  Referral source/Alternative education            n
# 3     0.04       All  Referral source/Alternative education            %
# 4   420.00       All      Referral source/Education service            n
#
#      Unit Clients in treatment
# 0  People    All young clients
# 1  People    All young clients
# 2  People    All young clients
# 3  People    All young clients
# 4  People    All young clients

# %%
new_table['Measure Type'] = new_table['Measure Type'].map(
    lambda x: {
        'n' : 'Count', 
        '%' : 'Percentage',
        }.get(x, x))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
new_table.tail()
# Out:
#        Value Substance                                 Basis of treatment  \
# 51      0.01       All                              Referral source/Other
# 52  17703.00       All                       Referral source/All episodes
# 53      1.00       All                       Referral source/All episodes
# 54     20.00       All       Referral source/Missing or inconsistent data
# 55  17723.00       All  Referral source/All episodes including missing...
#
#    Measure Type    Unit Clients in treatment
# 51   Percentage  People    All young clients
# 52        Count  People    All young clients
# 53   Percentage  People    All young clients
# 54        Count  People    All young clients
# 55        Count  People    All young clients

# %%
new_table.dtypes
# Out:
# Value                   float64
# Substance                object
# Basis of treatment       object
# Measure Type             object
# Unit                     object
# Clients in treatment     object
# dtype: object

# %%
new_table['Value'] = new_table['Value'].astype(str)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
new_table.head(3)
# Out:
#     Value Substance                     Basis of treatment Measure Type  \
# 0  3972.0       All   Referral source/Mainstream education        Count
# 1    0.22       All   Referral source/Mainstream education   Percentage
# 2   769.0       All  Referral source/Alternative education        Count
#
#      Unit Clients in treatment
# 0  People    All young clients
# 1  People    All young clients
# 2  People    All young clients

# %%
new_table['Period'] = '2016-17'
new_table = new_table[['Period','Basis of treatment','Substance','Clients in treatment','Measure Type','Value','Unit']]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
if is_interactive():
    SubstancetinationFolder = Path('out')
    SubstancetinationFolder.mkdir(exist_ok=True, parents=True)
    new_table.to_csv(SubstancetinationFolder / ('table2.4.1.csv'), index = False)

# %%
new_table.head()
# Out:
#     Period                     Basis of treatment Substance  \
# 0  2016-17   Referral source/Mainstream education       All
# 1  2016-17   Referral source/Mainstream education       All
# 2  2016-17  Referral source/Alternative education       All
# 3  2016-17  Referral source/Alternative education       All
# 4  2016-17      Referral source/Education service       All
#
#   Clients in treatment Measure Type   Value    Unit
# 0    All young clients        Count  3972.0  People
# 1    All young clients   Percentage    0.22  People
# 2    All young clients        Count   769.0  People
# 3    All young clients   Percentage    0.04  People
# 4    All young clients        Count   420.0  People
